# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# %%
sample_submission = pd.read_csv('./data/sample_submission.csv')
test_data = pd.read_csv('./data/test.csv')
train_data = pd.read_csv('./data/train.csv')

# %%
print(train_data.shape)
train_data.head()
# Out:
# (5872, 10)
#            ID  추석까지 남은 기간(주)  쇼핑몰 구분   가격(원)  프로모션 여부  도시 유형 지역 유형    쇼핑몰 유형  \
# 0  TRAIN_0000              1  쇼핑몰 15  212000        0   도시 6  지역 1  쇼핑몰 유형 2
# 1  TRAIN_0001              2  쇼핑몰 72  113000        0  도시 21  지역 1  쇼핑몰 유형 1
# 2  TRAIN_0002              0  쇼핑몰 15   67000        0   도시 6  지역 1  쇼핑몰 유형 2
# 3  TRAIN_0003              1  쇼핑몰 13  206000        0  도시 12  지역 3  쇼핑몰 유형 1
# 4  TRAIN_0004              1  쇼핑몰 65  140000        0  도시 16  지역 2  쇼핑몰 유형 2
#
#            선물 유형  수요량
# 0     명절혼합과일선물세트   28
# 1       발효홍삼선물세트   27
# 2       실속스팸선물세트  769
# 3  자연산프리미엄버섯선물세트   27
# 4      자연산새우선물세트  337

# %%
print(test_data.shape)
print(sample_submission.shape)
test_data.head()
# Out:
# (3915, 9)
# (3915, 2)
#           ID  추석까지 남은 기간(주)  쇼핑몰 구분   가격(원)  프로모션 여부  도시 유형 지역 유형    쇼핑몰 유형  \
# 0  TEST_0000              2  쇼핑몰 71  113000        0  도시 16  지역 3  쇼핑몰 유형 1
# 1  TEST_0001              0  쇼핑몰 57  224000        0   도시 6  지역 1  쇼핑몰 유형 2
# 2  TEST_0002              2  쇼핑몰 38  150000        0  도시 16  지역 1  쇼핑몰 유형 2
# 3  TEST_0003              1  쇼핑몰 50  132000        0  도시 16  지역 3  쇼핑몰 유형 1
# 4  TEST_0004              0  쇼핑몰 55  146000        0   도시 5  지역 4  쇼핑몰 유형 2
#
#          선물 유형
# 0  상주반건시곶감선물세트
# 1     고급한과선물세트
# 2  최고의선택스팸선물세트
# 3      재래김특선세트
# 4  명품샤인머스캣선물세트

# %%
train_data.rename(columns={
    '추석까지 남은 기간(주)' : 'week_to_chuseok',
    '쇼핑몰 구분' : 'mall',
    '가격(원)' : 'price',
    '프로모션 여부' : 'promotion',
    '도시 유형' : 'city_type',
    '지역 유형' : 'local_type',
    '쇼핑몰 유형' : 'mall_type',
    '선물 유형' : 'gift_type',
    '수요량' : 'demand'
}, inplace=True)

# %%
train_data.head()
# Out:
#            ID  week_to_chuseok    mall   price  promotion city_type  \
# 0  TRAIN_0000                1  쇼핑몰 15  212000          0      도시 6
# 1  TRAIN_0001                2  쇼핑몰 72  113000          0     도시 21
# 2  TRAIN_0002                0  쇼핑몰 15   67000          0      도시 6
# 3  TRAIN_0003                1  쇼핑몰 13  206000          0     도시 12
# 4  TRAIN_0004                1  쇼핑몰 65  140000          0     도시 16
#
#   local_type mall_type      gift_type  demand
# 0       지역 1  쇼핑몰 유형 2     명절혼합과일선물세트      28
# 1       지역 1  쇼핑몰 유형 1       발효홍삼선물세트      27
# 2       지역 1  쇼핑몰 유형 2       실속스팸선물세트     769
# 3       지역 3  쇼핑몰 유형 1  자연산프리미엄버섯선물세트      27
# 4       지역 2  쇼핑몰 유형 2      자연산새우선물세트     337

# %%
test_data.rename(columns={
    '추석까지 남은 기간(주)' : 'week_to_chuseok',
    '쇼핑몰 구분' : 'mall',
    '가격(원)' : 'price',
    '프로모션 여부' : 'promotion',
    '도시 유형' : 'city_type',
    '지역 유형' : 'local_type',
    '쇼핑몰 유형' : 'mall_type',
    '선물 유형' : 'gift_type',
    '수요량' : 'demand'
}, inplace=True)

# %%
test_data.head()
# Out:
#           ID  week_to_chuseok    mall   price  promotion city_type local_type  \
# 0  TEST_0000                2  쇼핑몰 71  113000          0     도시 16       지역 3
# 1  TEST_0001                0  쇼핑몰 57  224000          0      도시 6       지역 1
# 2  TEST_0002                2  쇼핑몰 38  150000          0     도시 16       지역 1
# 3  TEST_0003                1  쇼핑몰 50  132000          0     도시 16       지역 3
# 4  TEST_0004                0  쇼핑몰 55  146000          0      도시 5       지역 4
#
#   mall_type    gift_type
# 0  쇼핑몰 유형 1  상주반건시곶감선물세트
# 1  쇼핑몰 유형 2     고급한과선물세트
# 2  쇼핑몰 유형 2  최고의선택스팸선물세트
# 3  쇼핑몰 유형 1      재래김특선세트
# 4  쇼핑몰 유형 2  명품샤인머스캣선물세트

# %%
print(train_data['mall'].str.contains('쇼핑몰').sum())
print(train_data['city_type'].str.contains('도시').sum())
print(train_data['local_type'].str.contains('지역').sum())
print(train_data['mall_type'].str.contains('쇼핑몰 유형').sum())
# Out:
# 5872
# 5872
# 5872
# 5872

# %%
train_data['mall'] = train_data['mall'].str.replace('쇼핑몰', '').astype(int)
train_data['city_type'] = train_data['city_type'].str.replace('도시', '').astype(int)
train_data['local_type'] = train_data['local_type'].str.replace('지역', '').astype(int)
train_data['mall_type'] = train_data['mall_type'].str.replace('쇼핑몰 유형', '').astype(int)

# %%
train_data.head()
# Out:
#            ID  week_to_chuseok  mall   price  promotion  city_type  \
# 0  TRAIN_0000                1    15  212000          0          6
# 1  TRAIN_0001                2    72  113000          0         21
# 2  TRAIN_0002                0    15   67000          0          6
# 3  TRAIN_0003                1    13  206000          0         12
# 4  TRAIN_0004                1    65  140000          0         16
#
#    local_type  mall_type      gift_type  demand
# 0           1          2     명절혼합과일선물세트      28
# 1           1          1       발효홍삼선물세트      27
# 2           1          2       실속스팸선물세트     769
# 3           3          1  자연산프리미엄버섯선물세트      27
# 4           2          2      자연산새우선물세트     337

# %%
test_data['mall'] = test_data['mall'].str.replace('쇼핑몰', '').astype(int)
test_data['city_type'] = test_data['city_type'].str.replace('도시', '').astype(int)
test_data['local_type'] = test_data['local_type'].str.replace('지역', '').astype(int)
test_data['mall_type'] = test_data['mall_type'].str.replace('쇼핑몰 유형', '').astype(int)

# %%
test_data.head()
# Out:
#           ID  week_to_chuseok  mall   price  promotion  city_type  local_type  \
# 0  TEST_0000                2    71  113000          0         16           3
# 1  TEST_0001                0    57  224000          0          6           1
# 2  TEST_0002                2    38  150000          0         16           1
# 3  TEST_0003                1    50  132000          0         16           3
# 4  TEST_0004                0    55  146000          0          5           4
#
#    mall_type    gift_type
# 0          1  상주반건시곶감선물세트
# 1          2     고급한과선물세트
# 2          2  최고의선택스팸선물세트
# 3          1      재래김특선세트
# 4          2  명품샤인머스캣선물세트

# %%
train_data.head()
# Out:
#            ID  week_to_chuseok  mall   price  promotion  city_type  \
# 0  TRAIN_0000                1    15  212000          0          6
# 1  TRAIN_0001                2    72  113000          0         21
# 2  TRAIN_0002                0    15   67000          0          6
# 3  TRAIN_0003                1    13  206000          0         12
# 4  TRAIN_0004                1    65  140000          0         16
#
#    local_type  mall_type      gift_type  demand
# 0           1          2     명절혼합과일선물세트      28
# 1           1          1       발효홍삼선물세트      27
# 2           1          2       실속스팸선물세트     769
# 3           3          1  자연산프리미엄버섯선물세트      27
# 4           2          2      자연산새우선물세트     337

# %%
# 일단 gift_type가 한글데이터이므로 인코딩해줘야함
# mall, city_type, local_type, mall_type를 수로 표현했는데 이렇게 학습시키면 가까운 수 끼리 관계를 생성할 수 있음
# one-hot encoding으로 한다

# %%
sns.displot(train_data['demand'])
plt.show()
# Out:
# d:\Anaconda3\envs\jupyter\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(5, 5))
sns.barplot(x = train_data['week_to_chuseok'], y = train_data['demand'])
plt.show()

# %%
region_category = train_data['local_type'].value_counts().sort_index()
sns.barplot(x = region_category.index, y = region_category.values)
# Out:
# <Axes: xlabel='local_type'>

# %%
sns.boxplot(y = train_data['price'])
plt.show()
